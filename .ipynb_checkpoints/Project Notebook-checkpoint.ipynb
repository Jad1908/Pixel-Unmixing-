# %%
using Pkg
Pkg.add("Images")
Pkg.add("MAT")
# Out:
#     Updating registry at `C:\Users\ASUS\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed ImageIO ────────────────────────── v0.6.7
#    Installed GR_jll ─────────────────────────── v0.72.8+0
#    Installed TiledIteration ─────────────────── v0.5.0
#    Installed ImageSegmentation ──────────────── v1.8.2
#    Installed JpegTurbo ──────────────────────── v0.1.4
#    Installed PNGFiles ───────────────────────── v0.4.1
#    Installed AxisArrays ─────────────────────── v0.4.7
#    Installed TiffImages ─────────────────────── v0.6.8
#    Installed Preferences ────────────────────── v1.4.1
#    Installed HistogramThresholding ──────────── v0.3.1
#    Installed ImageMagick ────────────────────── v1.3.0
#    Installed LoggingExtras ──────────────────── v1.0.3
#    Installed RelocatableFolders ─────────────── v1.0.1
#    Installed Unitful ────────────────────────── v1.18.0
#    Installed RegionTrees ────────────────────── v0.3.2
#    Installed Sixel ──────────────────────────── v0.1.3
#    Installed PDMats ─────────────────────────── v0.11.29
#    Installed ConcurrentUtilities ────────────── v2.3.0
#    Installed StaticArrays ───────────────────── v1.6.5
#    Installed ProgressMeter ──────────────────── v1.9.0
#    Installed OpenEXR ────────────────────────── v0.3.2
#    Installed Images ─────────────────────────── v0.26.0
#    Installed FileIO ─────────────────────────── v1.16.1
#    Installed CEnum ──────────────────────────── v0.4.2
#    Installed MetaGraphs ─────────────────────── v0.7.2
#    Installed Netpbm ─────────────────────────── v1.1.1
#    Installed Polynomials ────────────────────── v3.2.13
#    Installed SLEEFPirates ───────────────────── v0.6.42
#    Installed Static ─────────────────────────── v0.8.8
#    Installed ColorSchemes ───────────────────── v3.24.0
#    Installed Distances ──────────────────────── v0.10.10
#    Installed JLD2 ───────────────────────────── v0.4.38
#    Installed RealDot ────────────────────────── v0.1.0
#    Installed GR ─────────────────────────────── v0.72.8
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed ArnoldiMethod ──────────────────── v0.2.0
#    Installed Qt5Base_jll ────────────────────── v5.15.3+2
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed Clustering ─────────────────────── v0.15.5
#    Installed xkbcommon_jll ──────────────────── v1.4.1+1
#    Installed QOI ────────────────────────────── v1.0.0
#    Installed SentinelArrays ─────────────────── v1.4.1
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed PkgVersion ─────────────────────── v0.3.3
#    Installed ThreadingUtilities ─────────────── v0.5.2
#    Installed fzf_jll ────────────────────────── v0.35.1+0
#    Installed TranscodingStreams ─────────────── v0.10.2
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed CustomUnitRanges ───────────────── v1.0.2
#    Installed ImageContrastAdjustment ────────── v0.3.12
#    Installed Graphics ───────────────────────── v1.1.2
#    Installed ImageMetadata ──────────────────── v0.9.9
#    Installed ComputationalResources ─────────── v0.3.2
#    Installed MbedTLS ────────────────────────── v1.1.8
#    Installed CatIndices ─────────────────────── v0.2.2
#    Installed MappedArrays ───────────────────── v0.4.2
#    Installed ImageMagick_jll ────────────────── v6.9.10-12+3
#    Installed JLFzf ──────────────────────────── v0.1.6
#    Installed PaddedViews ────────────────────── v0.5.12
#    Installed Compat ─────────────────────────── v4.10.0
#    Installed Graphs ─────────────────────────── v1.9.0
#    Installed ImageTransformations ───────────── v0.10.0
#    Installed StaticArrayInterface ───────────── v1.4.1
#    Installed LazyModules ────────────────────── v0.3.1
#    Installed CodecZlib ──────────────────────── v0.7.3
#    Installed MosaicViews ────────────────────── v0.3.4
#    Installed StatsBase ──────────────────────── v0.34.2
#    Installed ImageCorners ───────────────────── v0.1.3
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.5
#    Installed Scratch ────────────────────────── v1.2.1
#    Installed ImageCore ──────────────────────── v0.10.1
#    Installed LayoutPointers ─────────────────── v0.1.15
#    Installed Inflate ────────────────────────── v0.1.4
#    Installed Imath_jll ──────────────────────── v3.1.7+0
#    Installed Parsers ────────────────────────── v2.8.0
#    Installed ImageShow ──────────────────────── v0.3.8
#    Installed ImageQualityIndexes ────────────── v0.3.7
#    Installed IntegralArrays ─────────────────── v0.1.5
#    Installed PrettyTables ───────────────────── v2.3.0
#    Installed Libtiff_jll ────────────────────── v4.4.0+0
#    Installed ImageFiltering ─────────────────── v0.7.8
#    Installed CoordinateTransformations ──────── v0.6.3
#    Installed CommonEq ───────────────────────── v0.2.1
#    Installed ChainRulesCore ─────────────────── v1.18.0
#    Installed LoopVectorization ──────────────── v0.12.166
#    Installed PolyesterWeave ─────────────────── v0.2.1
#    Installed ArrayInterface ─────────────────── v7.5.1
#    Installed Quaternions ────────────────────── v0.7.4
#    Installed StackViews ─────────────────────── v0.1.1
#    Installed CloseOpenIntervals ─────────────── v0.1.12
#    Installed Rotations ──────────────────────── v1.6.1
#    Installed RangeArrays ────────────────────── v0.3.2
#    Installed UnPack ─────────────────────────── v1.0.2
#    Installed SimpleTraits ───────────────────── v0.9.4
#    Installed OpenEXR_jll ────────────────────── v3.1.4+0
#    Installed XML2_jll ───────────────────────── v2.11.5+0
#    Installed Adapt ──────────────────────────── v3.7.1
#    Installed VectorizationBase ──────────────── v0.21.64
#    Installed ImageBinarization ──────────────── v0.3.0
#    Installed Wayland_jll ────────────────────── v1.21.0+1
#    Installed BitFlags ───────────────────────── v0.1.8
#    Installed ImageBase ──────────────────────── v0.1.7
#    Installed IntervalSets ───────────────────── v0.7.8
#    Installed IndirectArrays ─────────────────── v1.0.0
#    Installed IterTools ──────────────────────── v1.8.0
#    Installed SimpleWeightedGraphs ───────────── v1.4.0
#    Installed CPUSummary ─────────────────────── v0.2.4
#    Installed Tables ─────────────────────────── v1.11.1
#    Installed ImageDistances ─────────────────── v0.2.17
#    Installed libsixel_jll ───────────────────── v1.10.3+0
#    Installed URIs ───────────────────────────── v1.5.1
#    Installed HostCPUFeatures ────────────────── v0.1.16
#    Installed FillArrays ─────────────────────── v1.7.0
#    Installed QuadGK ─────────────────────────── v2.9.1
#    Installed ImageAxes ──────────────────────── v0.6.11
#    Installed Observables ────────────────────── v0.5.5
#    Installed FFTViews ───────────────────────── v0.3.2
#    Installed Parameters ─────────────────────── v0.12.3
#    Installed SortingAlgorithms ──────────────── v1.2.0
#    Installed ImageMorphology ────────────────── v0.4.5
#     Updating `C:\Users\ASUS\.julia\environments\v1.9\Project.toml`
#   [916415d5] + Images v0.26.0
#     Updating `C:\Users\ASUS\.julia\environments\v1.9\Manifest.toml`
#   [79e6a3ab] ↑ Adapt v3.6.2 ⇒ v3.7.1
#   [ec485272] + ArnoldiMethod v0.2.0
#   [4fba245c] + ArrayInterface v7.5.1
#   [39de3d68] + AxisArrays v0.4.7
#   [d1d4a3ce] ↑ BitFlags v0.1.7 ⇒ v0.1.8
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.5
# ⌅ [fa961155] + CEnum v0.4.2
#   [2a0fbf3d] + CPUSummary v0.2.4
#   [aafaddc9] + CatIndices v0.2.2
#   [d360d2e6] ↑ ChainRulesCore v1.16.0 ⇒ v1.18.0
#   [fb6a15b2] + CloseOpenIntervals v0.1.12
#   [aaaa29a8] ↑ Clustering v0.15.4 ⇒ v0.15.5
#   [944b1d66] ↑ CodecZlib v0.7.2 ⇒ v0.7.3
#   [35d6a980] ↑ ColorSchemes v3.23.0 ⇒ v3.24.0
#   [3709ef60] ↑ CommonEq v0.2.0 ⇒ v0.2.1
#   [34da2185] ↑ Compat v4.9.0 ⇒ v4.10.0
#   [ed09eef8] + ComputationalResources v0.3.2
#   [f0e56b4a] ↑ ConcurrentUtilities v2.2.1 ⇒ v2.3.0
#   [150eb455] + CoordinateTransformations v0.6.3
#   [adafc99b] + CpuId v0.3.1
#   [dc8bdbbb] + CustomUnitRanges v1.0.2
#   [b4f34e82] ↑ Distances v0.10.9 ⇒ v0.10.10
#   [4f61f5a4] + FFTViews v0.3.2
#   [5789e2e9] + FileIO v1.16.1
#   [1a297f60] ↑ FillArrays v1.6.1 ⇒ v1.7.0
# ⌃ [28b8d3ca] ↓ GR v0.72.9 ⇒ v0.72.8
#   [a2bd30eb] + Graphics v1.1.2
#   [86223c79] + Graphs v1.9.0
#   [2c695a8d] + HistogramThresholding v0.3.1
#   [3e5b6fbb] + HostCPUFeatures v0.1.16
#   [615f187c] + IfElse v0.1.1
#   [2803e5a7] + ImageAxes v0.6.11
#   [c817782e] + ImageBase v0.1.7
#   [cbc4b850] + ImageBinarization v0.3.0
#   [f332f351] + ImageContrastAdjustment v0.3.12
#   [a09fc81d] + ImageCore v0.10.1
#   [89d5987c] + ImageCorners v0.1.3
#   [51556ac3] + ImageDistances v0.2.17
#   [6a3955dd] + ImageFiltering v0.7.8
#   [82e4d734] + ImageIO v0.6.7
#   [6218d12a] + ImageMagick v1.3.0
#   [bc367c6b] + ImageMetadata v0.9.9
#   [787d08f9] + ImageMorphology v0.4.5
#   [2996bd0c] + ImageQualityIndexes v0.3.7
#   [80713f31] + ImageSegmentation v1.8.2
#   [4e3cecfd] + ImageShow v0.3.8
#   [02fcd773] + ImageTransformations v0.10.0
#   [916415d5] + Images v0.26.0
#   [9b13fd28] + IndirectArrays v1.0.0
#   [d25df0c9] + Inflate v0.1.4
#   [1d092043] + IntegralArrays v0.1.5
#   [8197267c] + IntervalSets v0.7.8
#   [c8e1da08] + IterTools v1.8.0
#   [033835bb] + JLD2 v0.4.38
#   [1019f520] ↑ JLFzf v0.1.5 ⇒ v0.1.6
#   [b835a17e] + JpegTurbo v0.1.4
#   [10f19ff3] + LayoutPointers v0.1.15
#   [8cdb02fc] + LazyModules v0.3.1
#   [e6f89c97] ↑ LoggingExtras v1.0.2 ⇒ v1.0.3
#   [bdcacae8] + LoopVectorization v0.12.166
#   [d125e4d3] + ManualMemory v0.1.8
#   [dbb5928d] + MappedArrays v0.4.2
#   [739be429] ↑ MbedTLS v1.1.7 ⇒ v1.1.8
#   [626554b9] + MetaGraphs v0.7.2
#   [e94cdb99] + MosaicViews v0.3.4
#   [f09324ee] + Netpbm v1.1.1
#   [510215fc] ↑ Observables v0.5.4 ⇒ v0.5.5
#   [52e1d378] + OpenEXR v0.3.2
#   [90014a1f] ↑ PDMats v0.11.17 ⇒ v0.11.29
#   [f57f5aa1] + PNGFiles v0.4.1
#   [5432bcbf] + PaddedViews v0.5.12
#   [d96e819e] + Parameters v0.12.3
#   [69de0a69] ↑ Parsers v2.7.2 ⇒ v2.8.0
#   [eebad327] + PkgVersion v0.3.3
#   [1d0040c9] + PolyesterWeave v0.2.1
# ⌅ [f27b6e38] + Polynomials v3.2.13
#   [21216c6a] ↑ Preferences v1.4.0 ⇒ v1.4.1
#   [08abe8d2] ↑ PrettyTables v2.2.7 ⇒ v2.3.0
#   [92933f4c] + ProgressMeter v1.9.0
#   [4b34888f] + QOI v1.0.0
#   [1fd47b50] ↑ QuadGK v2.8.2 ⇒ v2.9.1
#   [94ee1d12] + Quaternions v0.7.4
#   [b3c3ace0] + RangeArrays v0.3.2
#   [c1ae055f] + RealDot v0.1.0
#   [dee08c22] + RegionTrees v0.3.2
#   [05181044] ↑ RelocatableFolders v1.0.0 ⇒ v1.0.1
#   [6038ab10] + Rotations v1.6.1
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.42
#   [6c6a2e73] ↑ Scratch v1.2.0 ⇒ v1.2.1
#   [91c51154] ↑ SentinelArrays v1.4.0 ⇒ v1.4.1
#   [699a6c99] + SimpleTraits v0.9.4
#   [47aef6b3] + SimpleWeightedGraphs v1.4.0
#   [45858cf5] + Sixel v0.1.3
#   [a2af1166] ↑ SortingAlgorithms v1.1.1 ⇒ v1.2.0
#   [cae243ae] + StackViews v0.1.1
#   [aedffcd0] + Static v0.8.8
#   [0d7ed370] + StaticArrayInterface v1.4.1
#   [90137ffa] ↑ StaticArrays v1.6.3 ⇒ v1.6.5
#   [2913bbd2] ↑ StatsBase v0.34.0 ⇒ v0.34.2
#   [bd369af6] ↑ Tables v1.10.1 ⇒ v1.11.1
#   [8290d209] + ThreadingUtilities v0.5.2
# ⌅ [731e570b] + TiffImages v0.6.8
#   [06e1c1a7] + TiledIteration v0.5.0
#   [3bb67fe8] ↑ TranscodingStreams v0.9.13 ⇒ v0.10.2
#   [5c2747f8] ↑ URIs v1.5.0 ⇒ v1.5.1
#   [3a884ed6] + UnPack v1.0.2
#   [1986cc42] ↑ Unitful v1.17.0 ⇒ v1.18.0
#   [3d5dd08c] + VectorizationBase v0.21.64
# ⌅ [d2c73de3] ↓ GR_jll v0.72.9+1 ⇒ v0.72.8+0
# ⌅ [c73af94c] + ImageMagick_jll v6.9.10-12+3
#   [905a6f67] + Imath_jll v3.1.7+0
# ⌅ [89763e89] ↓ Libtiff_jll v4.5.1+1 ⇒ v4.4.0+0
#   [18a262bb] + OpenEXR_jll v3.1.4+0
#   [ea2cea3b] + Qt5Base_jll v5.15.3+2
#   [c0090381] - Qt6Base_jll v6.4.2+3
#   [a2964d1f] ↑ Wayland_jll v1.21.0+0 ⇒ v1.21.0+1
#   [02c8fc9c] ↑ XML2_jll v2.10.4+0 ⇒ v2.11.5+0
#   [ffd25f8a] - XZ_jll v5.4.4+0
# ⌅ [214eeab7] ↑ fzf_jll v0.29.0+0 ⇒ v0.35.1+0
#   [075b6546] + libsixel_jll v1.10.3+0
#   [d8fb68d0] ↑ xkbcommon_jll v1.4.1+0 ⇒ v1.4.1+1
#         Info Packages marked with ⌃ and ⌅ have new versions available, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ Compat
#   ✓ IntervalSets
#   ✓ Observables
#   ✓ RealDot
#   ✓ URIs
#   ✓ CustomUnitRanges
#   ✓ CommonEq
#   ✓ ConcurrentUtilities
#   ✓ CpuId
#   ✓ ProgressMeter
#   ✓ UnPack
#   ✓ IterTools
#   ✓ LazyModules
#   ✓ MappedArrays
#   ✓ RangeArrays
#   ✓ IndirectArrays
#   ✓ ManualMemory
#   ✓ Inflate
#   ✓ IfElse
#   ✓ BitFlags
#   ✓ TranscodingStreams
#   ✓ Scratch
#   ✓ CEnum
#   ✓ FillArrays
#   ✓ PkgVersion
#   ✓ Preferences
#   ✓ SIMDTypes
#   ✓ ComputationalResources
#   ✓ SentinelArrays
#   ✓ LoggingExtras
#   ✓ SimpleTraits
#   ✓ Adapt
#   ✓ Distances
#   ✓ Tables
#   ✓ PDMats
#   ✓ MbedTLS
#   ✓ Compat → CompatLinearAlgebraExt
#   ✓ Graphics
#   ✓ IntervalSets → IntervalSetsStatisticsExt
#   ✓ ChainRulesCore
#   ✓ Quaternions
#   ✓ Widgets
#   ✓ Parameters
#   ✓ FileIO
#   ✓ Static
#   ✓ ThreadingUtilities
#   ✓ TranscodingStreams → TestExt
#   ✓ RelocatableFolders
#   ✓ CodecZlib
#   ✓ FillArrays → FillArraysSparseArraysExt
#   ✓ JLLWrappers
#   ✓ FillArrays → FillArraysStatisticsExt
#   ✓ PrecompileTools
#   ✓ Distances → DistancesSparseArraysExt
#   ✓ TableOperations
#   ✓ StaticArrays
#   ✓ IntegralArrays
#   ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#   ✓ AxisArrays
#   ✓ Distances → DistancesChainRulesCoreExt
#   ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#   ✓ DataStructures
#   ✓ BitTwiddlingConvenienceFunctions
#   ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#   ✓ OpenSSL_jll
#   ✓ QOI
#   ✓ libsodium_jll
#   ✓ Libffi_jll
#   ✓ Wayland_protocols_jll
#   ✓ Libuuid_jll
#   ✓ OpenSpecFun_jll
#   ✓ LLVMOpenMP_jll
#   ✓ Imath_jll
#   ✓ IntelOpenMP_jll
#   ✓ fzf_jll
#   ✓ JpegTurbo_jll
#   ✓ Ogg_jll
#   ✓ x265_jll
#   ✓ x264_jll
#   ✓ Libiconv_jll
#   ✓ FriBidi_jll
#   ✓ Graphite2_jll
#   ✓ EpollShim_jll
#   ✓ Xorg_libXau_jll
#   ✓ libpng_jll
#   ✓ LAME_jll
#   ✓ Xorg_libXdmcp_jll
#   ✓ Arpack_jll
#   ✓ libaom_jll
#   ✓ Zstd_jll
#   ✓ Expat_jll
#   ✓ LZO_jll
#   ✓ Opus_jll
#   ✓ Xorg_xtrans_jll
#   ✓ Libmount_jll
#   ✓ Bzip2_jll
#   ✓ Rmath_jll
#   ✓ libfdk_aac_jll
#   ✓ LERC_jll
#   ✓ Libgpg_error_jll
#   ✓ FFTW_jll
#   ✓ Xorg_libpthread_stubs_jll
#   ✓ RecipesBase
#   ✓ CPUSummary
#   ✓ StringManipulation
#   ✓ StaticArrays → StaticArraysStatisticsExt
#   ✓ ArnoldiMethod
#   ✓ Rotations
#   ✓ Adapt → AdaptStaticArraysExt
#   ✓ CoordinateTransformations
#   ✓ SortingAlgorithms
#   ✓ QuadGK
#   ✓ NearestNeighbors
#   ✓ HostCPUFeatures
#   ✓ ZeroMQ_jll
#   ✓ OpenSSL
#   ✓ Pixman_jll
#   ✓ OpenEXR_jll
#   ✓ MKL_jll
#   ✓ SpecialFunctions
#   ✓ Unitful
#   ✓ JLFzf
#   ✓ libvorbis_jll
#   ✓ XML2_jll
#   ✓ libsixel_jll
#   ✓ Arpack
#   ✓ FreeType2_jll
#   ✓ Rmath
#   ✓ Libtiff_jll
#   ✓ Libgcrypt_jll
#   ✓ PolyesterWeave
#   ✓ RegionTrees
#   ✓ Graphs
#   ✓ OffsetArrays
#   ✓ ArrayInterface
#   ✓ Parsers
#   ✓ JLD2
#   ✓ StatsBase
#   ✓ ZMQ
#   ✓ OpenEXR
#   ✓ HTTP
#   ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#   ✓ DualNumbers
#   ✓ ColorVectorSpace → SpecialFunctionsExt
#   ✓ Gettext_jll
#   ✓ Wayland_jll
#   ✓ UnitfulLatexify
#   ✓ Fontconfig_jll
#   ✓ XSLT_jll
#   ✓ ImageMagick_jll
#   ✓ PaddedViews
#   ✓ Polynomials
#   ✓ CatIndices
#   ✓ SimpleWeightedGraphs
#   ✓ StackViews
#   ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#   ✓ InlineStrings
#   ✓ Interpolations
#   ✓ JSON
#   ✓ FFTW
#   ✓ MetaGraphs
#   ✓ PrettyTables
#   ✓ Clustering
#   ✓ MultivariateStats
#   ✓ HypergeometricFunctions
#   ✓ Xorg_libxcb_jll
#   ✓ Glib_jll
#   ✓ Polynomials → PolynomialsChainRulesCoreExt
#   ✓ MosaicViews
#   ✓ Conda
#   ✓ FFTViews
#   ✓ StaticArrayInterface
#   ✓ Xorg_xcb_util_jll
#   ✓ Xorg_libX11_jll
#   ✓ StatsFuns
#   ✓ ColorSchemes
#   ✓ IJulia
#   ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#   ✓ CloseOpenIntervals
#   ✓ LayoutPointers
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ Xorg_libxkbfile_jll
#   ✓ StatsFuns → StatsFunsChainRulesCoreExt
#   ✓ PyCall
#   ✓ Distributions
#   ✓ TiledIteration
#   ✓ ImageCore
#   ✓ Xorg_libXinerama_jll
#   ✓ Libglvnd_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ Cairo_jll
#   ✓ Xorg_libXcursor_jll
#   ✓ Xorg_libXi_jll
#   ✓ PlotUtils
#   ✓ Xorg_xkbcomp_jll
#   ✓ Distributions → DistributionsChainRulesCoreExt
#   ✓ PyPlot
#   ✓ ImageBase
#   ✓ Sixel
#   ✓ VectorizationBase
#   ✓ ImageMagick
#   ✓ HarfBuzz_jll
#   ✓ JpegTurbo
#   ✓ GLFW_jll
#   ✓ PNGFiles
#   ✓ PlotThemes
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ RecipesPipeline
#   ✓ HistogramThresholding
#   ✓ TiffImages
#   ✓ ImageAxes
#   ✓ ImageShow
#   ✓ KernelDensity
#   ✓ SLEEFPirates
#   ✓ libass_jll
#   ✓ xkbcommon_jll
#   ✓ ImageTransformations
#   ✓ ImageMetadata
#   ✓ ImageBinarization
#   ✓ DataFrames
#   ✓ Qt5Base_jll
#   ✓ FFMPEG_jll
#   ✓ Netpbm
#   ✓ Latexify → DataFramesExt
#   ✓ ImageContrastAdjustment
#   ✓ FFMPEG
#   ✓ ImageIO
#   ✓ GR_jll
#   ✓ SymPy
#   ✓ GR
#   ✓ LoopVectorization
#   ✓ LoopVectorization → SpecialFunctionsExt
#   ✓ ImageMorphology
#   ✓ ImageDistances
#   ✓ ImageFiltering
#   ✓ ImageSegmentation
#   ✓ ImageCorners
#   ✓ ImageQualityIndexes
#   ✓ Images
#   ✓ Plots
#   ✓ Plots → FileIOExt
#   ✓ Plots → IJuliaExt
#   ✓ Plots → UnitfulExt
#   ✓ StatsPlots
#   251 dependencies successfully precompiled in 596 seconds. 55 already precompiled.
#   11 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions
#    Resolving package versions...
#    Installed BufferedStreams ─ v1.2.1
#    Installed MPIPreferences ── v0.1.10
#    Installed HDF5_jll ──────── v1.12.2+2
#    Installed MAT ───────────── v0.10.6
#    Installed HDF5 ──────────── v0.17.1
#     Updating `C:\Users\ASUS\.julia\environments\v1.9\Project.toml`
#   [23992714] + MAT v0.10.6
#     Updating `C:\Users\ASUS\.julia\environments\v1.9\Manifest.toml`
#   [e1450e63] + BufferedStreams v1.2.1
#   [f67ccb44] + HDF5 v0.17.1
#   [23992714] + MAT v0.10.6
#   [3da0fdf6] + MPIPreferences v0.1.10
# ⌃ [0234f1f7] + HDF5_jll v1.12.2+2
#         Info Packages marked with ⌃ have new versions available and may be upgradable.
# Precompiling project...
#   ✓ BufferedStreams
#   ✓ HDF5_jll
#   ✓ MPIPreferences
#   ✓ HDF5
#   ✓ MAT
#   5 dependencies successfully precompiled in 21 seconds. 306 already precompiled.

# %%
using MAT
using Plots
using Images


pyplot()

file = matopen("project_data.mat")
img = read(file, "im")
sources = read(file,"sources")
rgb = read(file,"rgb")
close(file)
# Out:
# [ Info: Precompiling MAT [23992714-dd62-5051-b70f-ba57cb901cac]
# [ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# │   exception = Required dependency RecipesPipeline [01d81517-befc-4cb6-b9ec-a95719d0359c] failed to load from a cache file.
# └ @ Base loading.jl:1818
# [ Info: Precompiling RecipesPipeline [01d81517-befc-4cb6-b9ec-a95719d0359c]
# [ Info: Precompiling JLFzf [1019f520-868f-41f5-a6de-eb00f4b6a39c]
# [ Info: Precompiling IJuliaExt [2f4121a4-3b3a-5ce6-9c5e-1f2673ce168a]
# ┌ Warning: Module Plots with build ID ffffffff-ffff-ffff-0000-4b81881c6fd9 is missing from the cache.
# │ This may mean Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1793
# [ Info: Skipping precompilation since __precompile__(false). Importing IJuliaExt [2f4121a4-3b3a-5ce6-9c5e-1f2673ce168a].
# [ Info: Precompiling Images [916415d5-f1e6-5110-898d-aaa5f9f070e0]

# %%
# visualize data in rgb (using bands 67,109,141 as th RGB channels)
p1 = colorview(RGB,permutedims(rgb,(3,1,2))) # convert 3d array to the image format used by julia

# %%
#visualize a spectral band on its own
p2 = heatmap(img[:,:,150],aspect_ratio=1, yflip = true,c=:ice)

# %%
# visualize the endmembers to be used

plot(sources[:,1],label = "gravel")
plot!(sources[:,2],label = "grass")
plot!(sources[:,3],label = "soil")
plot!(sources[:,4],label = "trees")
xlabel!("Spectral band")
ylabel!("Reflectance value")

# %% [markdown]
# # Unmixing the image
#
# The model we are using to decompose the image into the sum of the contributions of the endmembers is:
#
# \begin{equation*}
# \mathbf{X} = \mathbf{S}\mathbf{A} + \mathbf{E}
# \end{equation*}
#
#  $\mathbf{X}\in \mathbb{R}^{L\times N}$ : data matrix
#
#  $\mathbf{S}\in \mathbb{R}^{L\times P}$ : endmember matrix
#
#  $\mathbf{A}\in \mathbb{R}^{P\times N}$ : abundance matrix
#
#  $\mathbf{E}\in \mathbb{R}^{L\times N}$ : additive noise matrix
#
#  where $L$ is the number of spectral bands, $P$ is the number of materials, and $N$ is the number of pixels
#
#  The hyperspectral image is represented as a matrix with $N$ pixels, so the first thing to do is to reshape the image to a big matrix.
#
# We can try and estimate the abundance matrix using a least squares formulation:
#
# \begin{equation*}
# \hat{A} = \underset{\mathbf{A}>\mathbf{0}, \mathbf{1}_{P}^T \mathbf{A} = \mathbf{1}_{N}^{T} }{\textrm{arg min}}\frac{1}{2}||\mathbf{X}-\mathbf{SA}||_{F}^{2} = \underset{\mathbf{A}>\mathbf{0}, \mathbf{1}_{P}^T \mathbf{A} = \mathbf{1}_{N}^{T} }{\textrm{arg min}}\frac{1}{2} \sum_{i=1}^{N} ||\mathbf{x}_{n}-\mathbf{S}\mathbf{a}_{n}||_{2}^{2}
# \end{equation*}
#
# where $\mathbf{1}_{.}$ is a vector of ones whose size is given in index
#
# Choose an algorithm to solve the optimization problem, and implement it both in a serial version and a version parallelized across the pixels.

# %%
img_small = img[1:100,1:100,:]; # use a small crop of the image first
# img_small = copy(img);

# %%
function projected_gradient_descent(X, S, A_init, max_iter, tol)
    # X: Data matrix (L x N)
    # S: Endmember matrix (L x P)
    # A_init: Initial estimate of the abundance matrix (P x N)
    # max_iter: Maximum number of iterations
    # tol: Convergence tolerance
    
    A = copy(A_init)
    
    for iter in 1:max_iter
        # Compute the gradient of the objective function
        gradient = compute_gradient(X, S, A)
        
        # Update estimate using gradient descent
        A -= 0.01 * gradient  # Adjust the step size (learning rate) as needed
        
        # Project onto the feasible set
        A = project_onto_feasible_set(A)
        
        # Check for convergence
        if norm(gradient) < tol
            println("Converged after $iter iterations.")
            break
        end
    end
    
    return A
end

function compute_gradient(X, S, A)
    # Compute the gradient of the objective function
    return -S' * (X - S * A)
end

function project_onto_feasible_set(A)
    # Project onto the non-negativity constraint
    A[A .< 0] .= 0
    
    # Project onto the equality constraint
    A /= sum(A, dims=1)
    
    return A
end

# %%
# Example usage
L = 3  # Number of spectral bands
P = 4  # Number of materials
N = 1000  # Number of pixels

# Generate synthetic data
X = randn(L, N)
S = randn(L, P)
A_init = rand(P, N)

# Run the projected gradient descent algorithm
max_iter = 1000
tol = 1e-6
estimated_A = projected_gradient_descent(X, S, A_init, max_iter, tol)
